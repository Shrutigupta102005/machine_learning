# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.9 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 538.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 640.0 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 656.4 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 651.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 652.2 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 554.9 kB/s eta 0:00:21
# ...

# %%
import pandas as pd

# %%
import numpy as np
